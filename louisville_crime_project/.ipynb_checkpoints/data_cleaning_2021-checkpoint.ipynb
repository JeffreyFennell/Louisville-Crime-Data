# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Louisville_Metro_KY_-_Crime_Data_2021.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72123 entries, 0 to 72122
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INCIDENT_NUMBER  72123 non-null  object
#  1   DATE_REPORTED    72123 non-null  object
#  2   DATE_OCCURED     72123 non-null  object
#  3   BADGE_ID         72121 non-null  object
#  4   CRIME_TYPE       72123 non-null  object
#  5   UOR_DESC         72123 non-null  object
#  6   NIBRS_CODE       72123 non-null  object
#  7   UCR_HIERARCHY    69811 non-null  object
#  8   ATT_COMP         72050 non-null  object
#  9   LMPD_DIVISION    72123 non-null  object
#  10  LMPD_BEAT        72117 non-null  object
#  11  PREMISE_TYPE     72114 non-null  object
#  12  BLOCK_ADDRESS    72123 non-null  object
#  13  City             72112 non-null  object
#  14  ZIP_CODE         72098 non-null  float64
#  15  ObjectId         72123 non-null  int64
# ...

# %%
df.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED          BADGE_ID  \
# 0    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00  8403
# 1    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00  8403
# 2    80-21-000003  2021/01/01 00:03:00  2021/01/01 00:03:00  7939
# 3    80-21-000005  2021/01/01 00:14:00  2021/01/01 00:13:00  5293
# 4    80-21-000006  2021/01/01 00:03:00  2020/12/31 23:03:00  5258
#
#   CRIME_TYPE                        UOR_DESC NIBRS_CODE UCR_HIERARCHY  \
# 0  VANDALISM  CRIMINAL MISCHIEF - 1ST DEGREE        290       PART II
# 1   BURGLARY           BURGLARY - 2ND DEGREE        220        PART I
# 2    ASSAULT            ASSAULT - 1ST DEGREE        13A        PART I
# 3    ASSAULT  WANTON ENDANGERMENT-1ST DEGREE        13A        PART I
# 4  VANDALISM  CRIMINAL MISCHIEF - 1ST DEGREE        290       PART II
#
#     ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0  COMPLETED  6TH DIVISION       613
# 1  COMPLETED  6TH DIVISION       613
# ...

# %%
ndf = df.drop(columns=['ATT_COMP', 'UCR_HIERARCHY', 'NIBRS_CODE', 'LMPD_BEAT','ObjectId', 'BADGE_ID'])

# %%
ndf.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED CRIME_TYPE  \
# 0    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00  VANDALISM
# 1    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00   BURGLARY
# 2    80-21-000003  2021/01/01 00:03:00  2021/01/01 00:03:00    ASSAULT
# 3    80-21-000005  2021/01/01 00:14:00  2021/01/01 00:13:00    ASSAULT
# 4    80-21-000006  2021/01/01 00:03:00  2020/12/31 23:03:00  VANDALISM
#
#                          UOR_DESC LMPD_DIVISION  \
# 0  CRIMINAL MISCHIEF - 1ST DEGREE  6TH DIVISION
# 1           BURGLARY - 2ND DEGREE  6TH DIVISION
# 2            ASSAULT - 1ST DEGREE  1ST DIVISION
# 3  WANTON ENDANGERMENT-1ST DEGREE  3RD DIVISION
# 4  CRIMINAL MISCHIEF - 1ST DEGREE  4TH DIVISION
#
#                                     PREMISE_TYPE  \
# 0  RESIDENCE / HOME
# 1  RESIDENCE / HOME
# 2  HIGHWAY / ROAD / ALLEY
# 3  RESIDENCE / HOME
# 4  DEPARTMENT / DISCOUNT STORE
#
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72123 entries, 0 to 72122
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INCIDENT_NUMBER  72123 non-null  object
#  1   DATE_REPORTED    72123 non-null  object
#  2   DATE_OCCURED     72123 non-null  object
#  3   CRIME_TYPE       72123 non-null  object
#  4   UOR_DESC         72123 non-null  object
#  5   LMPD_DIVISION    72123 non-null  object
#  6   PREMISE_TYPE     72114 non-null  object
#  7   BLOCK_ADDRESS    72123 non-null  object
#  8   City             72112 non-null  object
#  9   ZIP_CODE         72098 non-null  float64
# dtypes: float64(1), object(9)
# memory usage: 5.5+ MB

# %%
ndf['ZIP_CODE'] = ndf['ZIP_CODE'].fillna(0)

# %%
ndf['ZIP_CODE'] = ndf['ZIP_CODE'].astype(int)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72123 entries, 0 to 72122
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INCIDENT_NUMBER  72123 non-null  object
#  1   DATE_REPORTED    72123 non-null  object
#  2   DATE_OCCURED     72123 non-null  object
#  3   CRIME_TYPE       72123 non-null  object
#  4   UOR_DESC         72123 non-null  object
#  5   LMPD_DIVISION    72123 non-null  object
#  6   PREMISE_TYPE     72114 non-null  object
#  7   BLOCK_ADDRESS    72123 non-null  object
#  8   City             72112 non-null  object
#  9   ZIP_CODE         72123 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 5.5+ MB

# %%
ndf.head()
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED CRIME_TYPE  \
# 0    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00  VANDALISM
# 1    80-20-077625  2021/01/01 04:10:00  2020/12/31 20:00:00   BURGLARY
# 2    80-21-000003  2021/01/01 00:03:00  2021/01/01 00:03:00    ASSAULT
# 3    80-21-000005  2021/01/01 00:14:00  2021/01/01 00:13:00    ASSAULT
# 4    80-21-000006  2021/01/01 00:03:00  2020/12/31 23:03:00  VANDALISM
#
#                          UOR_DESC LMPD_DIVISION  \
# 0  CRIMINAL MISCHIEF - 1ST DEGREE  6TH DIVISION
# 1           BURGLARY - 2ND DEGREE  6TH DIVISION
# 2            ASSAULT - 1ST DEGREE  1ST DIVISION
# 3  WANTON ENDANGERMENT-1ST DEGREE  3RD DIVISION
# 4  CRIMINAL MISCHIEF - 1ST DEGREE  4TH DIVISION
#
#                                     PREMISE_TYPE  \
# 0  RESIDENCE / HOME
# 1  RESIDENCE / HOME
# 2  HIGHWAY / ROAD / ALLEY
# 3  RESIDENCE / HOME
# 4  DEPARTMENT / DISCOUNT STORE
#
# ...

# %%
ndf['DATE_REPORTED'] = pd.to_datetime(ndf['DATE_REPORTED'])
ndf['DATE_OCCURED'] = pd.to_datetime(ndf['DATE_OCCURED'])
ndf.info()
ndf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72123 entries, 0 to 72122
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INCIDENT_NUMBER  72123 non-null  object
#  1   DATE_REPORTED    72123 non-null  datetime64[ns]
#  2   DATE_OCCURED     72123 non-null  datetime64[ns]
#  3   CRIME_TYPE       72123 non-null  object
#  4   UOR_DESC         72123 non-null  object
#  5   LMPD_DIVISION    72123 non-null  object
#  6   PREMISE_TYPE     72114 non-null  object
#  7   BLOCK_ADDRESS    72123 non-null  object
#  8   City             72112 non-null  object
#  9   ZIP_CODE         72123 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(7)
# memory usage: 5.5+ MB
#   INCIDENT_NUMBER       DATE_REPORTED        DATE_OCCURED CRIME_TYPE  \
# 0    80-20-077625 2021-01-01 04:10:00 2020-12-31 20:00:00  VANDALISM
# 1    80-20-077625 2021-01-01 04:10:00 2020-12-31 20:00:00   BURGLARY
# ...

# %%
ndf = ndf.drop(columns=['INCIDENT_NUMBER'])

# %%
ndf.head()
# Out:
#         DATE_REPORTED        DATE_OCCURED CRIME_TYPE  \
# 0 2021-01-01 04:10:00 2020-12-31 20:00:00  VANDALISM
# 1 2021-01-01 04:10:00 2020-12-31 20:00:00   BURGLARY
# 2 2021-01-01 00:03:00 2021-01-01 00:03:00    ASSAULT
# 3 2021-01-01 00:14:00 2021-01-01 00:13:00    ASSAULT
# 4 2021-01-01 00:03:00 2020-12-31 23:03:00  VANDALISM
#
#                          UOR_DESC LMPD_DIVISION  \
# 0  CRIMINAL MISCHIEF - 1ST DEGREE  6TH DIVISION
# 1           BURGLARY - 2ND DEGREE  6TH DIVISION
# 2            ASSAULT - 1ST DEGREE  1ST DIVISION
# 3  WANTON ENDANGERMENT-1ST DEGREE  3RD DIVISION
# 4  CRIMINAL MISCHIEF - 1ST DEGREE  4TH DIVISION
#
#                                     PREMISE_TYPE  \
# 0  RESIDENCE / HOME
# 1  RESIDENCE / HOME
# 2  HIGHWAY / ROAD / ALLEY
# 3  RESIDENCE / HOME
# 4  DEPARTMENT / DISCOUNT STORE
#
#                                        BLOCK_ADDRESS        City  ZIP_CODE
# 0  4100 BLOCK ST FRANCIS LN                      ...  LOUISVILLE     40218
# ...

# %%
# ndf.to_csv('Clean_Louisville_Metro_KY_-_Crime_Data_2021.csv')

# %%
len(ndf['CRIME_TYPE'])
# Out:
# 72123

# %%
# ndf.plot(x="ZIP_CODE", y=[len("CRIME_TYPE")], kind="bar")
# plt.show()
ndf.plot(kind = 'bar', x = 'QUANTITY', y = 'SALES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nt/33j272z93nq7qmv7sqkq4x8m0000gn/T/ipykernel_24674/2252782796.py in <module>
#       1 # ndf.plot(x="ZIP_CODE", y=[len("CRIME_TYPE")], kind="bar")
#       2 # plt.show()
# ----> 3 lures.plot(kind = 'scatter', x = 'QUANTITY', y = 'SALES')
#
# NameError: name 'lures' is not defined
